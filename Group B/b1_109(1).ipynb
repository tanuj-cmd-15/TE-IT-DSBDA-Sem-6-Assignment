# %% [markdown]
# # Perform the following operations using Python on the Facebook metrics data sets
#
# a. Create data subsets
#
#  b. Merge Data
#
# c. Sort Data
#
# d. Transposing Data
#
# e. Shape and reshape Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

# %%
A = pd.read_csv(r"Facebook.csv")

# %%
A
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
A.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
A.dtypes
# Out:
# Page total likes                                                         int64
# Type                                                                    object
# Category                                                                 int64
# Post Month                                                               int64
# Post Weekday                                                             int64
# Post Hour                                                                int64
# Paid                                                                   float64
# Lifetime Post Total Reach                                                int64
# Lifetime Post Total Impressions                                          int64
# Lifetime Engaged Users                                                   int64
# Lifetime Post Consumers                                                  int64
# Lifetime Post Consumptions                                               int64
# ...

# %%
A.head(5)
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# # Create a data subset

# %%
sub1=A[['Type','Category']]
sub1
# Out:
#        Type  Category
# 0     Photo         2
# 1    Status         2
# 2     Photo         3
# 3     Photo         2
# 4     Photo         2
# ..      ...       ...
# 495   Photo         3
# 496   Photo         2
# 497   Photo         1
# 498   Photo         3
# 499   Photo         2
#
# [500 rows x 2 columns]

# %%
sub2 = A.loc[0:4]
sub2
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
sub3= A.iloc[[0,1,3,6],[0,1,2]]
sub3
# Out:
#    Page total likes    Type  Category
# 0            139441   Photo         2
# 1            139441  Status         2
# 3            139441   Photo         2
# 6            139441   Photo         3

# %% [markdown]
# # Merge Dataset

# %%
m1=sub2.merge(sub3)
m1.head(5)
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441   Photo         2          12             4          3
# 2            139441   Photo         2          12             4          3
# 3            139441  Status         2          12             3         10
# 4            139441  Status         2          12             3         10
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                       2752                             5091
# 2   0.0                       2752                             5091
# 3   0.0                      10460                            19057
# 4   0.0                      10460                            19057
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
m3 = sub1.merge(sub2,left_index=True,right_index=True)
m3
# Out:
#    Type_x  Category_x  Page total likes  Type_y  Category_y  Post Month  \
# 0   Photo           2            139441   Photo           2          12
# 1  Status           2            139441  Status           2          12
# 2   Photo           3            139441   Photo           3          12
# 3   Photo           2            139441   Photo           2          12
# 4   Photo           2            139441   Photo           2          12
#
#    Post Weekday  Post Hour  Paid  Lifetime Post Total Reach  ...  \
# 0             4          3   0.0                       2752  ...
# 1             3         10   0.0                      10460  ...
# 2             3          3   0.0                       2413  ...
# 3             2         10   1.0                      50128  ...
# 4             2          3   0.0                       7244  ...
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# 0                     178                      109
# ...

# %%
m3 = sub2.merge(sub3,on = None)
m3.head(5)
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441   Photo         2          12             4          3
# 2            139441   Photo         2          12             4          3
# 3            139441  Status         2          12             3         10
# 4            139441  Status         2          12             3         10
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                       2752                             5091
# 2   0.0                       2752                             5091
# 3   0.0                      10460                            19057
# 4   0.0                      10460                            19057
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# # Sort Data

# %%
st1 =A.sort_values(by ='Type')
st1.head(5)
# Out:
#      Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 438             98195  Link         2           3             6          6
# 470             91437  Link         1           2             3         13
# 41             138895  Link         1          12             6          3
# 43             138353  Link         1          12             5          3
# 45             138353  Link         1          12             4          3
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 438   0.0                       5730                            10083
# 470   0.0                       9356                            14986
# 41    1.0                      18480                            28438
# 43    1.0                       2645                             4270
# 45    1.0                       7968                            13023
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
st2 =A.sort_values(by =['Type', 'Category'])
st2.head(5)
# Out:
#     Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22            138414  Link         1          12             7         10
# 41            138895  Link         1          12             6          3
# 43            138353  Link         1          12             5          3
# 45            138353  Link         1          12             4          3
# 47            138353  Link         1          12             3          2
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 22   0.0                       3454                             6853
# 41   1.0                      18480                            28438
# 43   1.0                       2645                             4270
# 45   1.0                       7968                            13023
# 47   0.0                       1925                             3481
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# # Transposing Data

# %%
tp =A.transpose()
tp.head(5)
# Out:
#                      0       1       2       3       4       5       6    \
# Page total likes  139441  139441  139441  139441  139441  139441  139441
# Type               Photo  Status   Photo   Photo   Photo  Status   Photo
# Category               2       2       3       2       2       2       3
# Post Month            12      12      12      12      12      12      12
# Post Weekday           4       3       3       2       2       1       1
#
#                      7       8       9    ...    490    491    492    493  \
# Page total likes  139441  139441  139441  ...  85979  85979  85979  85093
# Type               Photo  Status   Photo  ...  Photo  Photo   Link  Photo
# Category               3       2       3  ...      3      3      1      3
# Post Month            12      12      12  ...      1      1      1      1
# Post Weekday           7       7       6  ...      6      6      5      1
#
#                     494    495    496    497    498    499
# ...

# %% [markdown]
# # Shape and Reshape data

# %%
rshape1= A.melt(id_vars=['Type'],value_vars=['Category','Paid'])

# %%
rshape1
# Out:
#        Type  variable  value
# 0     Photo  Category    2.0
# 1    Status  Category    2.0
# 2     Photo  Category    3.0
# 3     Photo  Category    2.0
# 4     Photo  Category    2.0
# ..      ...       ...    ...
# 995   Photo      Paid    0.0
# 996   Photo      Paid    0.0
# 997   Photo      Paid    0.0
# 998   Photo      Paid    0.0
# 999   Photo      Paid    NaN
#
# [1000 rows x 3 columns]

# %%
A.melt(id_vars=['Type'],value_vars=['Post Month','Paid'])
# Out:
#        Type    variable  value
# 0     Photo  Post Month   12.0
# 1    Status  Post Month   12.0
# 2     Photo  Post Month   12.0
# 3     Photo  Post Month   12.0
# 4     Photo  Post Month   12.0
# ..      ...         ...    ...
# 995   Photo        Paid    0.0
# 996   Photo        Paid    0.0
# 997   Photo        Paid    0.0
# 998   Photo        Paid    0.0
# 999   Photo        Paid    NaN
#
# [1000 rows x 3 columns]
