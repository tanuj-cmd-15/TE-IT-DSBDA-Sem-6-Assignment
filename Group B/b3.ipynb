# %% [markdown]
# # Problem Statement:
# Visualize the data using Python libraries matplotlib,seaborn by plotting the graphs for assignment no.2 and 3.

# %% [markdown]
# #### Import The libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
A =pd.read_csv("airquality.csv")

# %%
A
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day Humidity
# 0             1   41.0    190.0   7.4    67      5    1     High
# 1             2   36.0    118.0   8.0    72      5    2      low
# 2             3   12.0    149.0  12.6    74      5    3      low
# 3             4   18.0    313.0  11.5    62      5    4     High
# 4             5    NaN      NaN  14.3    56      5    5   Medium
# ..          ...    ...      ...   ...   ...    ...  ...      ...
# 148         149   30.0    193.0   6.9    70      9   26      low
# 149         150    NaN    145.0  13.2    77      9   27     High
# 150         151   14.0    191.0  14.3    75      9   28     High
# 151         152   18.0    131.0   8.0    76      9   29      low
# 152         153   20.0    223.0  11.5    68      9   30      low
#
# [153 rows x 8 columns]

# %%
A.head(5)
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day Humidity
# 0           1   41.0    190.0   7.4    67      5    1     High
# 1           2   36.0    118.0   8.0    72      5    2      low
# 2           3   12.0    149.0  12.6    74      5    3      low
# 3           4   18.0    313.0  11.5    62      5    4     High
# 4           5    NaN      NaN  14.3    56      5    5   Medium

# %%
A.tail(5)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day Humidity
# 148         149   30.0    193.0   6.9    70      9   26      low
# 149         150    NaN    145.0  13.2    77      9   27     High
# 150         151   14.0    191.0  14.3    75      9   28     High
# 151         152   18.0    131.0   8.0    76      9   29      low
# 152         153   20.0    223.0  11.5    68      9   30      low

# %%
A.shape
# Out:
# (153, 8)

# %%
A.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone         37
# Solar.R        7
# Wind           0
# Temp           0
# Month          0
# Day            0
# Humidity       6
# dtype: int64

# %% [markdown]
# #### Replacing the null values

# %%
A["Ozone"]=A["Ozone"].fillna(A["Ozone"].mean())
A["Solar.R"]=A["Solar.R"].fillna(A["Solar.R"].mean())

# %%
A
# Out:
#      Unnamed: 0     Ozone     Solar.R  Wind  Temp  Month  Day Humidity
# 0             1  41.00000  190.000000   7.4    67      5    1     High
# 1             2  36.00000  118.000000   8.0    72      5    2      low
# 2             3  12.00000  149.000000  12.6    74      5    3      low
# 3             4  18.00000  313.000000  11.5    62      5    4     High
# 4             5  42.12931  185.931507  14.3    56      5    5   Medium
# ..          ...       ...         ...   ...   ...    ...  ...      ...
# 148         149  30.00000  193.000000   6.9    70      9   26      low
# 149         150  42.12931  145.000000  13.2    77      9   27     High
# 150         151  14.00000  191.000000  14.3    75      9   28     High
# 151         152  18.00000  131.000000   8.0    76      9   29      low
# 152         153  20.00000  223.000000  11.5    68      9   30      low
#
# [153 rows x 8 columns]

# %%
A.drop('Unnamed: 0',axis=1,inplace=True)

# %%
A
# Out:
#         Ozone     Solar.R  Wind  Temp  Month  Day Humidity
# 0    41.00000  190.000000   7.4    67      5    1     High
# 1    36.00000  118.000000   8.0    72      5    2      low
# 2    12.00000  149.000000  12.6    74      5    3      low
# 3    18.00000  313.000000  11.5    62      5    4     High
# 4    42.12931  185.931507  14.3    56      5    5   Medium
# ..        ...         ...   ...   ...    ...  ...      ...
# 148  30.00000  193.000000   6.9    70      9   26      low
# 149  42.12931  145.000000  13.2    77      9   27     High
# 150  14.00000  191.000000  14.3    75      9   28     High
# 151  18.00000  131.000000   8.0    76      9   29      low
# 152  20.00000  223.000000  11.5    68      9   30      low
#
# [153 rows x 7 columns]

# %% [markdown]
# #### PIE CHART

# %%
A.columns
# Out:
# Index(['Ozone', 'Solar.R', 'Wind', 'Temp', 'Month', 'Day', 'Humidity'], dtype='object')

# %%
labels = ['Ozone','Solar.R','Wind','Temp']

# %%
Sizes= [A['Ozone'].mean(),A['Solar.R'].mean(),A['Wind'].mean(),A['Temp'].mean()]

# %%
colors=['red','green','yellow','orange']

# %%
explode=(0.1,0,0,0)

# %%
plt.pie(Sizes,explode=explode,labeldistance=1.1,labels=labels,colors=colors,autopct='%1.1f%%')
plt.title('Average Data')
plt.show()

# %% [markdown]
# #### Bar Plot

# %%
def addlabels():
    for i in range(len(A.iloc[0:21,3])):
        plt.text(i,A.iloc[0:21,3][i],A.iloc[0:21,3][i],ha='center')
y=np.arange(len(A.iloc[0:21,3]))
plt.figure(figsize=(10,6))
addlabels()
plt.bar(x=y,height=A.iloc[0:21,3],tick_label=y,color="dodgerblue")
plt.title('Wind measure for 1st-20th May')
plt.xlabel('Days')
plt.ylabel('Wind')
plt.show()

# %% [markdown]
# #### BOX Plot

# %%
A.boxplot(column=['Ozone','Wind','Temp','Solar.R'],grid=True)
plt.title('Box-Plot')
plt.suptitle('Temperature')
plt.ylabel('range')
plt.savefig('plot3.png')

# %% [markdown]
# #### HISTROGRAM

# %%
plt.figure(figsize=(10,6))
plt.hist(x=A['Temp'],bins=20,color="Red",label="Temp")
plt.title("Temperature count")
plt.xlabel("Temperature")
plt.ylabel("count")
plt.plot()
# Out:
# []

# %% [markdown]
# #### SCATTER Plot

# %%
plt.figure(figsize=(10,6))
plt.scatter(A.iloc[0:30,5],A.iloc[0:30,2],color="green")
plt.title("Wind measures of May month")
plt.xlabel("Day")
plt.ylabel("Wind")
# Out:
# Text(0, 0.5, 'Wind')

# %% [markdown]
# #### PAIR Plot

# %%
import seaborn 
seaborn.pairplot(A.iloc[:,[0,1,2,3,6]],hue='Humidity')
plt.show()

# %% [markdown]
# #### HEATMAP

# %%
seaborn.heatmap(data=A.iloc[0:30,[0,1,2,3]])
plt.show()

# %% [markdown]
# #### Line graph

# %%
plt.figure(figsize=(10,4))
plt.plot(A.iloc[0:30,5],A.iloc[0:30,3],color="blue")
plt.title('Temperature of May month')
plt.xlabel("Day")
plt.ylabel('Temperature')
# Out:
# Text(0, 0.5, 'Temperature')

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
A
# Out:
#         Ozone     Solar.R  Wind  Temp  Month  Day Humidity
# 0    41.00000  190.000000   7.4    67      5    1     High
# 1    36.00000  118.000000   8.0    72      5    2      low
# 2    12.00000  149.000000  12.6    74      5    3      low
# 3    18.00000  313.000000  11.5    62      5    4     High
# 4    42.12931  185.931507  14.3    56      5    5   Medium
# ..        ...         ...   ...   ...    ...  ...      ...
# 148  30.00000  193.000000   6.9    70      9   26      low
# 149  42.12931  145.000000  13.2    77      9   27     High
# 150  14.00000  191.000000  14.3    75      9   28     High
# 151  18.00000  131.000000   8.0    76      9   29      low
# 152  20.00000  223.000000  11.5    68      9   30      low
#
# [153 rows x 7 columns]

# %%
plt.plot(A.iloc[0:30,5],A.iloc[0:30,3],color="blue",label="Line 1")
plt.plot(A.iloc[0:30,5],A.iloc[0:30,2],color="blue")
plt.plot(A.iloc[0:30,5],A.iloc[0:30,1],color="blue")

plt.figure(figsize=(16,6))

# %%
fig, ax = plt.subplots()
ax.plot(A.iloc[0:30,5],A.iloc[0:30,3], label='Line 1')
ax.plot(A.iloc[0:30,5],A.iloc[0:30,2], label='Line 1')
ax.plot(A.iloc[0:30,5],A.iloc[0:30,0], label='Line 1')
ax.plot(A.iloc[0:30,5],A.iloc[0:30,0], label='Line 1')

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud ,STOPWORDS
stopwords=set(STOPWORDS)
text=""" Cybersecurity means protecting data, networks, programs and other information from unauthorized or unattended access, destruction or change. In today’s world, cybersecurity is very important because of some security threats and cyber-attacks. For data protection, many companies develop software. This software protects the data. Cybersecurity is important because not only it helps to secure information but also our system from virus attack. After the U.S.A. and China, India has the highest number of internet users. """

wordcloud=WordCloud(width=800,height=800,background_color='white',stopwords=stopwords,min_font_size=10).generate(text)
plt.figure(figsize=(5,5))
plt.imshow(wordcloud)
plt.axis("off")
